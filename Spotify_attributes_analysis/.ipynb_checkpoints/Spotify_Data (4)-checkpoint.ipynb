# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#create a reference to csv file
file_path = ("../Resources/Spotify_data.csv")
#Read csv file 
spotify_df = pd.read_csv(file_path)
#print first 5 rows
spotify_df.head()
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    2    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    5    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    5    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target      song_title            artist
# 0               4    0.286       1        Mask Off            Future
# 1               4    0.588       1         Redbone  Childish Gambino
# 2               4    0.173       1    Xanny Family            Future
# 3               4    0.230       1  Master Of None       Beach House
# 4               4    0.904       1  Parallel Lines       Junior Boys

# %%
#check the names of all columns and check rows for missing data
spotify_df.count()
# Out:
# Unnamed: 0          2017
# acousticness        2017
# danceability        2017
# duration_ms         2017
# energy              2017
# instrumentalness    2017
# key                 2017
# liveness            2017
# loudness            2017
# mode                2017
# speechiness         2017
# tempo               2017
# time_signature      2017
# valence             2017
# target              2017
# song_title          2017
# artist              2017
# dtype: int64

# %%
#remove rows with missing data
cleaned_rows_df = spotify_df.dropna(how="any")
cleaned_rows_df.count()
# Out:
# Unnamed: 0          2017
# acousticness        2017
# danceability        2017
# duration_ms         2017
# energy              2017
# instrumentalness    2017
# key                 2017
# liveness            2017
# loudness            2017
# mode                2017
# speechiness         2017
# tempo               2017
# time_signature      2017
# valence             2017
# target              2017
# song_title          2017
# artist              2017
# dtype: int64

# %%
cleaned_rows_df.columns
# Out:
# Index(['Unnamed: 0', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'target',
#        'song_title', 'artist'],
#       dtype='object')

# %%
# #remove unwanted columns
reduced_df = cleaned_rows_df[['acousticness', 'danceability', 'duration_ms', 'energy',
       'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'target',
       'song_title', 'artist']]
reduced_df.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  \
# 0        0.0102         0.833       204600   0.434          0.021900
# 1        0.1990         0.743       326933   0.359          0.006110
# 2        0.0344         0.838       185707   0.412          0.000234
# 3        0.6040         0.494       199413   0.338          0.510000
# 4        0.1800         0.678       392893   0.561          0.512000
#
#    liveness  loudness  speechiness    tempo  valence  target      song_title  \
# 0    0.1650    -8.795       0.4310  150.062    0.286       1        Mask Off
# 1    0.1370   -10.401       0.0794  160.083    0.588       1         Redbone
# 2    0.1590    -7.148       0.2890   75.044    0.173       1    Xanny Family
# 3    0.0922   -15.236       0.0261   86.468    0.230       1  Master Of None
# 4    0.4390   -11.648       0.0694  174.004    0.904       1  Parallel Lines
#
#              artist
# 0            Future
# 1  Childish Gambino
# 2            Future
# 3       Beach House
# 4       Junior Boys

# %%
#Identify duplicates
duplicates_df = reduced_df[reduced_df.duplicated()]
print("Duplicate Rows:\n", duplicates_df)
# Out:
# Duplicate Rows:
#       acousticness  danceability  duration_ms  energy  instrumentalness  \
# 267      0.096200         0.654       252095   0.292          0.003100
# 508      0.024600         0.586       374133   0.806          0.000167
# 894      0.000334         0.907       183581   0.616          0.425000
# 927      0.934000         0.440       254360   0.433          0.811000
# 981      0.036900         0.448       258653   0.733          0.042500
#
#      liveness  loudness  speechiness    tempo  valence  target  \
# 267     0.106   -12.977       0.4740  153.547    0.111       1
# 508     0.353    -9.542       0.0548  110.325    0.207       1
# 894     0.110    -7.073       0.0577  124.036    0.614       1
# 927     0.273   -17.453       0.0412   79.952    0.217       1
# 981     0.169    -6.238       0.0292  142.008    0.404       1
#
#                         song_title         artist
# 267                          River          Ibeyi
# 508                    Her Fantasy   Matthew Dear
# 894                           Jack         Breach
# 927  Episode I - Duel of The Fates  John Williams
# 981                           Myth    Beach House

# %%
# Drop duplicates
duplicates_cleaned_spotify = reduced_df.drop_duplicates()
duplicates_cleaned_spotify.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  \
# 0        0.0102         0.833       204600   0.434          0.021900
# 1        0.1990         0.743       326933   0.359          0.006110
# 2        0.0344         0.838       185707   0.412          0.000234
# 3        0.6040         0.494       199413   0.338          0.510000
# 4        0.1800         0.678       392893   0.561          0.512000
#
#    liveness  loudness  speechiness    tempo  valence  target      song_title  \
# 0    0.1650    -8.795       0.4310  150.062    0.286       1        Mask Off
# 1    0.1370   -10.401       0.0794  160.083    0.588       1         Redbone
# 2    0.1590    -7.148       0.2890   75.044    0.173       1    Xanny Family
# 3    0.0922   -15.236       0.0261   86.468    0.230       1  Master Of None
# 4    0.4390   -11.648       0.0694  174.004    0.904       1  Parallel Lines
#
#              artist
# 0            Future
# 1  Childish Gambino
# 2            Future
# 3       Beach House
# 4       Junior Boys

# %%
duplicates_cleaned_spotify.count()
# Out:
# acousticness        2012
# danceability        2012
# duration_ms         2012
# energy              2012
# instrumentalness    2012
# liveness            2012
# loudness            2012
# speechiness         2012
# tempo               2012
# valence             2012
# target              2012
# song_title          2012
# artist              2012
# dtype: int64

# %%
duplicates_cleaned_spotify.describe()
# Out:
#        acousticness  danceability   duration_ms       energy  \
# count   2012.000000   2012.000000  2.012000e+03  2012.000000
# mean       0.187513      0.618450  2.462608e+05     0.681840
# std        0.259691      0.161003  8.202146e+04     0.210255
# min        0.000003      0.122000  1.604200e+04     0.014800
# 25%        0.009590      0.514000  2.000045e+05     0.563750
# 50%        0.063500      0.631000  2.291200e+05     0.715500
# 75%        0.265000      0.738000  2.703565e+05     0.846000
# max        0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness     liveness     loudness  speechiness        tempo  \
# count       2012.000000  2012.000000  2012.000000  2012.000000  2012.000000
# mean           0.132980     0.190816    -7.076750     0.092568   121.602351
# std            0.272967     0.155571     3.756502     0.089615    26.687988
# min            0.000000     0.018800   -33.097000     0.023100    47.859000
# 25%            0.000000     0.092200    -8.392250     0.037500   100.164000
# 50%            0.000074     0.126500    -6.247500     0.054900   121.407000
# 75%            0.053925     0.246250    -4.744000     0.108000   137.695250
# max            0.976000     0.969000    -0.307000     0.816000   219.331000
#
#            valence       target
# count  2012.000000  2012.000000
# mean      0.497278     0.516402
# std       0.247167     0.499855
# min       0.034800     0.000000
# 25%       0.296000     0.000000
# 50%       0.493000     1.000000
# 75%       0.692000     1.000000
# max       0.992000     1.000000

# %%
# Identify outliners
def identify_outliers(duplicates_cleaned_spotify, col):
    Q1 = duplicates_cleaned_spotify[col].quantile(0.25)
    Q3 = duplicates_cleaned_spotify[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return duplicates_cleaned_spotify[(duplicates_cleaned_spotify[col] < lower_bound) | (duplicates_cleaned_spotify[col] > upper_bound)]

# Identify outliers for each numeric column
numeric_cols = duplicates_cleaned_spotify.select_dtypes(include=[np.number]).columns
outliers_dict = {col: identify_outliers(duplicates_cleaned_spotify, col) for col in numeric_cols}

# %%
# def remove_outliers(duplicates_cleaned_spotify, col):
#     Q1 = duplicates_cleaned_spotify[col].quantile(0.25)
#     Q3 = duplicates_cleaned_spotify[col].quantile(0.75)
#     IQR = Q3 - Q1
#     lower_bound = Q1 - 1.5 * IQR
#     upper_bound = Q3 + 1.5 * IQR
#     return duplicates_cleaned_spotify[(duplicates_cleaned_spotify[col] >= lower_bound) & (duplicates_cleaned_spotify[col] <= upper_bound)]

# # Remove outliers for each numeric column
# duplicates_cleaned_spotify = duplicates_cleaned_spotify.copy()
# for col in numeric_cols:
#     cleaned_spotify_complete = remove_outliers(duplicates_cleaned_spotify, col)

# %%
def replace_outliers_with_median(duplicates_cleaned_spotify, col):
    Q1 = duplicates_cleaned_spotify[col].quantile(0.25)
    Q3 = duplicates_cleaned_spotify[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    median_value = duplicates_cleaned_spotify[col].median()
    duplicates_cleaned_spotify[col] = np.where((duplicates_cleaned_spotify[col] < lower_bound) | (duplicates_cleaned_spotify[col] > upper_bound),
                       median_value, duplicates_cleaned_spotify[col])
    return duplicates_cleaned_spotify

# Replace outliers for each numeric column
duplicates_cleaned_spotify = duplicates_cleaned_spotify.copy()
for col in numeric_cols:
    cleaned_spotify_complete = replace_outliers_with_median(duplicates_cleaned_spotify, col)

# %%
#rename columns
renamed_spotify_complete = cleaned_spotify_complete.rename(columns={"song_title": "song", "artist": "singer"})
renamed_spotify_complete.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  \
# 0        0.0102         0.833     204600.0   0.434          0.000073
# 1        0.1990         0.743     229120.0   0.359          0.000073
# 2        0.0344         0.838     185707.0   0.412          0.000073
# 3        0.0634         0.494     199413.0   0.338          0.000074
# 4        0.1800         0.678     229120.0   0.561          0.000074
#
#    liveness  loudness  speechiness    tempo  valence  target            song  \
# 0   0.16500   -8.7950       0.0549  150.062    0.286     1.0        Mask Off
# 1   0.13700  -10.4010       0.0794  160.083    0.588     1.0         Redbone
# 2   0.15900   -7.1480       0.0549   75.044    0.173     1.0    Xanny Family
# 3   0.09220   -6.2475       0.0261   86.468    0.230     1.0  Master Of None
# 4   0.12625  -11.6480       0.0694  174.004    0.904     1.0  Parallel Lines
#
#              singer
# 0            Future
# 1  Childish Gambino
# 2            Future
# 3       Beach House
# 4       Junior Boys

# %%
# Create a dictionary from the DataFrame columns
data = {
    'song': renamed_spotify_complete['song'].tolist(),
    'acousticness': renamed_spotify_complete['acousticness'].tolist(),
    'danceability': renamed_spotify_complete['danceability'].tolist(),
    'energy': renamed_spotify_complete['energy'].tolist(),
    'loudness': renamed_spotify_complete['loudness'].tolist(),
    'speechiness':renamed_spotify_complete['speechiness'].tolist(),
    'liveness': renamed_spotify_complete['liveness'].tolist(),
    'valence': renamed_spotify_complete['valence'].tolist(),
    'tempo':renamed_spotify_complete['tempo'].tolist(),
    'duration_ms': renamed_spotify_complete['duration_ms'].tolist(),
    'instrumentalness': renamed_spotify_complete['instrumentalness'].tolist(),
    'target': renamed_spotify_complete['target'].tolist(),
    'singer': renamed_spotify_complete['singer'].tolist()
}

# Create DataFrame from the dictionary
spotify_complete = pd.DataFrame(data)
spotify_complete.head()
# Out:
#              song  acousticness  danceability  energy  loudness  speechiness  \
# 0        Mask Off        0.0102         0.833   0.434   -8.7950       0.0549
# 1         Redbone        0.1990         0.743   0.359  -10.4010       0.0794
# 2    Xanny Family        0.0344         0.838   0.412   -7.1480       0.0549
# 3  Master Of None        0.0634         0.494   0.338   -6.2475       0.0261
# 4  Parallel Lines        0.1800         0.678   0.561  -11.6480       0.0694
#
#    liveness  valence    tempo  duration_ms  instrumentalness  target  \
# 0   0.16500    0.286  150.062     204600.0          0.000073     1.0
# 1   0.13700    0.588  160.083     229120.0          0.000073     1.0
# 2   0.15900    0.173   75.044     185707.0          0.000073     1.0
# 3   0.09220    0.230   86.468     199413.0          0.000074     1.0
# 4   0.12625    0.904  174.004     229120.0          0.000074     1.0
#
#              singer
# 0            Future
# 1  Childish Gambino
# 2            Future
# 3       Beach House
# 4       Junior Boys

# %%
numeric_cols = ['acousticness', 'danceability', 'duration_ms', 'energy','instrumentalness', 'liveness', 'loudness', 'speechiness',
                'tempo', 'valence', 'target']
spotify_complete[numeric_cols].hist(bins=20, figsize=(15, 10))
plt.savefig('../images/numeric_cols_histograms.png', format='png')
plt.show()

# %%
# Filter liked and unliked songs 
liked_songs = spotify_complete[spotify_complete['target'] == 1] 
unliked_songs = spotify_complete[spotify_complete['target'] == 0]

# %%
singer_counts = liked_songs['singer'].value_counts().head(20)
singer_counts
# Out:
# singer
# Drake                     13
# Disclosure                12
# WALK THE MOON              9
# Crystal Castles            9
# FIDLAR                     9
# Kanye West                 8
# CHVRCHES                   7
# Young Thug                 7
# Hot Chip                   6
# Grimes                     6
# ASTR                       6
# M83                        6
# Future                     6
# ILoveMakonnen              5
# Tame Impala                5
# A$AP Ferg                  5
# Beach House                5
# Purity Ring                5
# Teams vs. Star Slinger     5
# New Order                  5
# Name: count, dtype: int64

# %%
#create bar chart showing popularity of artists
plt.figure(figsize=(8, 8))
singer_counts.plot(kind='bar', color='lightgreen') 
plt.xlabel('Top Twenty Singers') 
plt.ylabel('Number of Songs') 
plt.title('Number of Songs by Singer') 
plt.xticks(rotation=90)
plt.savefig('../images/top_20_singers.png', format='png')
plt.show()

# %%
liked_count = len(liked_songs)
unliked_count = len(unliked_songs)

# %%
labels = ['Liked Songs', 'Unliked Songs']
sizes = [liked_count, unliked_count]
colors = ['orange', 'lightgreen']
explode = (0.1, 0)  # explode the first slice (Liked Songs)

# Plotting the pie chart 
plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode,labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, shadow=True)
plt.title('Distribution of Liked and Unliked Songs')
plt.savefig('../images/liked_unliked_songs.png', format='png')
plt.show()

# %%
# Plot box plot
plt.figure(figsize=(10, 6))
plt.boxplot([liked_songs['duration_ms'], unliked_songs['duration_ms']], labels=['Liked', 'Unliked'], patch_artist=True)
plt.xlabel('Likeability')
plt.ylabel('Duration (ms)')
plt.title('Duration vs Likeability')
plt.savefig('../images/duration_on_likeability.png', format='png')
plt.show()

# %%
# Calculate average danceability for each singer
singer_danceability = liked_songs.groupby('singer')['danceability'].mean()
singer_popularity = liked_songs['singer'].value_counts()

# Plot scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(singer_danceability, singer_popularity, color='red', edgecolor='black')
plt.xlabel('Average Danceability')
plt.ylabel('Popularity')
plt.title('Danceability vs Popularity of Artists')
plt.savefig('../images/danceability_on_popularity.png', format='png')
plt.show()

# %%
# Plot histograms for tempo
plt.figure(figsize=(10, 6))
plt.hist(liked_songs['tempo'], bins=30, alpha=0.5, label='Liked Songs', color='orange', edgecolor='black')
plt.hist(unliked_songs['tempo'], bins=30, alpha=0.5, label='Unliked Songs', color='skyblue', edgecolor='black')
plt.xlabel('Tempo (BPM)')
plt.ylabel('Count')
plt.title('Tempo vs Likeability')
plt.savefig('../images/Tempo_on_likeability.png', format='png')
plt.legend()
plt.show()

# %%
# Plot histograms
plt.figure(figsize=(10, 6))
plt.hist(liked_songs['energy'], bins=30, alpha=0.5, label='Liked Songs', color='orange', edgecolor='black')
plt.hist(unliked_songs['energy'], bins=30, alpha=0.5, label='Unliked Songs', color='blue', edgecolor='black')
plt.xlabel('Energy')
plt.ylabel('Count')
plt.title('Energy vs Likeability')
plt.legend()
plt.savefig('../images/Energy_on_likeability.png', format='png')
plt.show()

# %%
# Plot histograms
plt.figure(figsize=(10, 6))
plt.hist(liked_songs['valence'], bins=30, alpha=0.5, label='Liked Songs', color='red', edgecolor='black')
plt.hist(unliked_songs['valence'], bins=30, alpha=0.5, label='Unliked Songs', color='yellow', edgecolor='black')
plt.xlabel('Valence')
plt.ylabel('Count')
plt.title('Valence vs Likeability')
plt.legend()
plt.savefig('../images/Valence_on_likeability.png', format='png')
plt.show()

# %%
# Plot histograms
plt.figure(figsize=(10, 6))
plt.hist(liked_songs['loudness'], bins=30, alpha=0.5, label='Liked Songs', color='magenta', edgecolor='black')
plt.hist(unliked_songs['loudness'], bins=30, alpha=0.5, label='Unliked Songs', color='limegreen', edgecolor='black')
plt.xlabel('Instrumentalness')
plt.ylabel('Count')
plt.title('Instrumentalness vs Likeability')
plt.legend()
plt.savefig('../images/Instrumentalness_on_likeability.png', format='png')
plt.show()

# %%
from scipy.stats import ttest_ind

# Separate the liked and unliked songs
danceability_liked_songs = spotify_complete[spotify_complete['target'] == 1]['danceability']
danceability_unliked_songs = spotify_complete[spotify_complete['target'] == 0]['danceability']

# Perform the independent t-test
t_stat, p_value = ttest_ind(danceability_liked_songs, danceability_unliked_songs)

print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: 7.794409995807346, P-value: 1.0299895145824112e-14

# %%
from scipy.stats import f_oneway

# Perform ANOVA for multiple groups (e.g., different genres)
anova_results = f_oneway(
    spotify_complete[spotify_complete['target'] == 1]['danceability'],
    spotify_complete[spotify_complete['target'] == 0]['danceability'],
    spotify_complete[spotify_complete['target'] == 1]['tempo'],
    spotify_complete[spotify_complete['target'] == 0]['tempo']
)

print(f"F-statistic: {anova_results.statistic}, P-value: {anova_results.pvalue}")
# Out:
# F-statistic: 15025.90741942658, P-value: 0.0
